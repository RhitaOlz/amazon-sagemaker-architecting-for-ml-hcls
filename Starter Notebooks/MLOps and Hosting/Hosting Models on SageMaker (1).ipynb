# %% [markdown]
# # Hosting Models on SageMaker and Automate the Workflow
#
# In this module you will:
# - Host a pretrained SKLearn model on SageMaker
# - Enable autoscaling on your endpoint
# - Monitor your model
# - Perform hyperparameter tuning
# - Redploy a new model to the endpoint
# - Automate the pipeline using the notebook runner toolkit
#
# Let's get started!
#
# ---

# %% [markdown]
# ### 1. Access your model artifact
# First, you should see a `model.tar.gz` file in this repository. Let's get that in your S3 bucket.

# %%
import sagemaker
import os

sess = sagemaker.Session()

# sagemaker will check to make sure this is a valid tar.gz object
local_model_file = 'model.tar.gz'

bucket = sess.default_bucket()

prefix = 'model-hosting'

s3_path = 's3://{}/{}/'.format(bucket, prefix)

msg = 'aws s3 cp {} {}'.format(local_model_file, s3_path)

os.system(msg)
# Out:
# 0

# %% [markdown]
# ### 2. Load your pretrained model artifact into SageMaker
# Now, we know that this model was trained using the SKLearn container within SageMaker. All we need to do get this into a SageMaker-managed endpoint is set it up as a model. Let's do that here!

# %%
model_data = '{}{}'.format(s3_path, local_model_file)
print (model_data)
# Out:
# s3://sagemaker-us-east-1-138066269299/model-hosting/model.tar.gz

# %%
# %%writefile train.py

import argparse
import pandas as pd
import numpy as np
import os

from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.externals import joblib

def model_fn(model_dir):
    """Deserialized and return fitted model

    Note that this should have the same name as the serialized model in the main method
    """
    regr = joblib.load(os.path.join(model_dir, "model.joblib"))
    return regr

def predict_fn(input_data, model):
    '''return the class and the probability of the class'''
    prediction = model.predict(input_data)
    pred_prob = model.predict_proba(input_data) #a numpy array
    return np.array(pred_prob)

def parse_args():
    
    # Hyperparameters are described here. In this simple example we are just including one hyperparameter.

    parser = argparse.ArgumentParser()
    
    parser.add_argument('--max_leaf_nodes', type=int, default=-1)

   # Sagemaker specific arguments. Defaults are set in the environment variables.
    parser.add_argument('--output-data-dir', type=str, default=os.environ['SM_OUTPUT_DATA_DIR'])
    parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
    parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
    parser.add_argument('--test', type=str, default = os.environ['SM_CHANNEL_TEST'])
    
    # hyperparameters for tuning
    parser.add_argument('--batch-size', type=int, default=256)
    parser.add_argument('--lr', type=float, default = 0.001)
    
    args = parser.parse_args()
    
    return args

def train(args):
    
   # Take the set of files and read them all into a single pandas dataframe
    train_data=pd.read_csv(os.path.join(args.train, 'train_set.csv'), engine='python')

    # labels are in the first column
    train_y = train_data['truth']
    train_X = train_data[train_data.columns[1:len(train_data)]]

    # Now use scikit-learn's MLP Classifier to train the model.

    regr = MLPClassifier(random_state=1, max_iter=500, batch_size = args.batch_size, learning_rate_init = args.lr, solver='lbfgs').fit(train_X, train_y)
    regr.get_params()

    # Print the coefficients of the trained classifier, and save the coefficients
    joblib.dump(regr, os.path.join(args.model_dir, "model.joblib")) 
    
    return regr
    
def accuracy(y_pred, y_true):
    
    cm = confusion_matrix(y_pred, y_true)
    
    diagonal_sum = cm.trace()
    sum_of_all_elements = cm.sum()
    
    rt = diagonal_sum / sum_of_all_elements
    
    print ('Accuracy: {}'.format(rt))
    
    return rt
    
    
def test(regr, args):
    test_data=pd.read_csv(os.path.join(args.test, 'test_set.csv'), engine='python')

    # labels are in the first column
    y_true = test_data['truth']
    test_x = test_data[test_data.columns[1:len(test_data)]]
    
    y_pred = regr.predict(test_x)
    
    accuracy(y_pred, y_true)
    
if __name__ == '__main__':

    args = parse_args()
    
    regr = train(args)
    
    test(regr, args)
# Out:
# Overwriting train.py

# %%
from sagemaker.sklearn.model import SKLearnModel

role = sagemaker.get_execution_role()

model = SKLearnModel(model_data = model_data,
                     role = role, 
                     framework_version = '0.20.0', 
                     py_version='py3',
                     entry_point = 'train.py')

# %% [markdown]
# ### 3. Create an Endpoint on SageMaker
# Now, here comes the complex maneuver. Kidding, it's dirt simple. Let's turn your model into a RESTful API!

# %%
predictor = model.deploy(1, 'ml.m4.2xlarge') # Endpoint creation
# Out:
# ---------------!

# %%
import sagemaker

from sagemaker.sklearn.model import SKLearnPredictor
sess = sagemaker.Session()

# optional. If your kernel times out, or your need to refresh, here's how you can easily point to an existing endpoint
# endpoint_name = 'sagemaker-scikit-learn-2020-10-14-15-12-50-644'
endpoint_name = 'sagemaker-scikit-learn-2020-10-29-20-38-35-161'

predictor = SKLearnPredictor(endpoint_name = endpoint_name, sagemaker_session = sess)

# %% [markdown]
# Now let's get some predictions from that endpoint.

# %%
import pandas as pd
test_set = pd.read_csv('test_set.csv')

# %%
y_true = test_set['truth']

test_set.drop('truth', inplace=True, axis=1)

# %%
import pandas as pd

y_pred = pd.DataFrame(predictor.predict(test_set))

assert len(y_pred) == test_set.shape[0]

# %% [markdown]
# ### 4. Enable Autoscaling on your Endpoint
# For the sake of argument, let's say we're happy with this model and want to continue supporting it in prod. Our next step might be to enable autoscaling. Let's do that right here.

# %%
import boto3

def get_resource_id(endpoint_name):

    client = boto3.client('sagemaker')

    response = client.describe_endpoint(
        EndpointName=endpoint_name)

    variant_name = response['ProductionVariants'][0]['VariantName']
    resource_id = 'endpoint/{}/variant/{}'.format(endpoint_name, variant_name)
    
    return resource_id

resource_id = get_resource_id(endpoint_name)

# %%
import boto3

role = sagemaker.get_execution_role()

def set_scaling_policy(resource_id, min_capacity = 1, max_capacity = 8, role = role):

    scaling_client = boto3.client('application-autoscaling')

    response = scaling_client.register_scalable_target(
        ServiceNamespace='sagemaker',
        ResourceId=resource_id,
        ScalableDimension='sagemaker:variant:DesiredInstanceCount',
        MinCapacity=min_capacity,
        MaxCapacity=max_capacity,
        RoleARN=role)
    
    return response

res = set_scaling_policy(resource_id)

# %% [markdown]
# ### 5. Enable Model Monitor on your Endpoint
# Now that you have a model up and running, with autoscaling enabled, let's set up model monitor on that endpoint.

# %%
import sagemaker
import os

sess = sagemaker.Session()

bucket = sess.default_bucket()

prefix = 'model-hosting'

s3_capture_upload_path =  's3://{}/{}/model-monitor'.format(bucket, prefix)

print ('about to set up monitoring for endpoint named {}'.format(endpoint_name))
# Out:
# about to set up monitoring for endpoint named sagemaker-scikit-learn-2020-10-29-20-38-35-161

# %% [markdown]
# Now, let's set up a data capture config.

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
                        enable_capture = True,
                        sampling_percentage=50,
                        destination_s3_uri=s3_capture_upload_path,
                        capture_options=["REQUEST", "RESPONSE"],
                        csv_content_types=["text/csv"],
                        json_content_types=["application/json"])

# Now it is time to apply the new configuration and wait for it to be applied
predictor.update_data_capture_config(data_capture_config=data_capture_config)

sess.wait_for_endpoint(endpoint=endpoint_name)
# Out:
# ---------------!!
# {'EndpointName': 'sagemaker-scikit-learn-2020-10-29-20-38-35-161',
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:138066269299:endpoint/sagemaker-scikit-learn-2020-10-29-20-38-35-161',
#  'EndpointConfigName': 'sagemaker-scikit-learn-2020-10-29-20-38-2020-10-29-20-57-41-094',
#  'ProductionVariants': [{'VariantName': 'AllTraffic',
#    'DeployedImages': [{'SpecifiedImage': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3',
#      'ResolvedImage': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn@sha256:1476311657fe444be8f95f472a8a91a3da577d558e1046678ee76c611f7132ca',
#      'ResolutionTime': datetime.datetime(2020, 10, 29, 20, 57, 44, 896000, tzinfo=tzlocal())}],
#    'CurrentWeight': 1.0,
#    'DesiredWeight': 1.0,
#    'CurrentInstanceCount': 1,
#    'DesiredInstanceCount': 1}],
#  'DataCaptureConfig': {'EnableCapture': True,
#   'CaptureStatus': 'Started',
#   'CurrentSamplingPercentage': 50,
#   'DestinationS3Uri': 's3://sagemaker-us-east-1-138066269299/model-hosting/model-monitor'},
#  'EndpointStatus': 'InService',
#  'CreationTime': datetime.datetime(2020, 10, 29, 20, 38, 35, 480000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2020, 10, 29, 21, 4, 59, 927000, tzinfo=tzlocal()),
#  'ResponseMetadata': {'RequestId': '5a879bc2-6ec1-4af4-b284-46883deb6712',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '5a879bc2-6ec1-4af4-b284-46883deb6712',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1005',
#    'date': 'Thu, 29 Oct 2020 21:05:13 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# Next step here is to pass in our training data, and ask SageMaker to learn baseline thresholds for all of our features.
#
# First, let's make sure the data we used to train our model is stored in S3.

# %%
msg = 'aws s3 cp train_set.csv s3://{}/{}/train/'.format(bucket, prefix)
os.system(msg)
# Out:
# 0

# %%
# todo - show them how to get access to this training data
s3_training_data_path = 's3://{}/{}/train/train_set.csv'.format(bucket, prefix)

s3_baseline_results =  's3://{}/{}/model-monitor/baseline-results'.format(bucket, prefix)

# %%
from sagemaker.model_monitor import DefaultModelMonitor
from sagemaker.model_monitor.dataset_format import DatasetFormat

my_default_monitor = DefaultModelMonitor(
    role=role,
    instance_count=1,
    instance_type='ml.m5.xlarge',
    volume_size_in_gb=20,
    max_runtime_in_seconds=3600,
)

my_default_monitor.suggest_baseline(
    baseline_dataset=s3_training_data_path,
    
    # change header to false if not included
    dataset_format=DatasetFormat.csv(header=False),
    output_s3_uri=s3_baseline_results,
    wait=True
)
# Out:
# Job Name:  baseline-suggestion-job-2020-10-29-21-07-58-410
# Inputs:  [{'InputName': 'baseline_dataset_input', 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-138066269299/model-hosting/train/train_set.csv', 'LocalPath': '/opt/ml/processing/input/baseline_dataset_input', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'monitoring_output', 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-138066269299/model-hosting/model-monitor/baseline-results', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..........................2020-10-29 21:12:04,943 - __main__ - INFO - All params:{'ProcessingJobArn': 'arn:aws:sagemaker:us-east-1:138066269299:processing-job/baseline-suggestion-job-2020-10-29-21-07-58-410', 'ProcessingJobName': 'baseline-suggestion-job-2020-10-29-21-07-58-410', 'Environment': {'dataset_format': '{"csv": {"header": false, "output_columns_position": "START"}}', 'dataset_source': '/opt/ml/processing/input/baseline_dataset_input', 'output_path': '/opt/ml/processing/output', 'publish_cloudwatch_metrics': 'Disabled'}, 'AppSpecification': {'ImageUri': '156813124566.dkr.ecr.us-east-1.amazonaws.com/sagemaker-model-monitor-analyzer', 'ContainerEntrypoint': None, 'ContainerArguments': None}, 'ProcessingInputs': [{'InputName': 'baseline_dataset_input', 'S3Input': {'LocalPath': '/opt/ml/processing/input/baseline_dataset_input', 'S3Uri': 's3://sagemaker-us-east-1-138066269299/model-hosting/train/train_set.csv', 'S3DataDistributionType': 'FullyReplicated', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3CompressionType': 'None', 'S3DownloadMode': 'StartOfJob'}}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'monitoring_output', 'S3Output': {'LocalPath': '/opt/ml/processing/output', 'S3Uri': 's3://sagemaker-us-east-1-138066269299/model-hosting/model-monitor/baseline-results', 'S3UploadMode': 'EndOfJob'}, 'FeatureStoreOutput': None}], 'KmsKeyId': None}, 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 1, 'InstanceType': 'ml.m5.xlarge', 'VolumeSizeInGB': 20, 'VolumeKmsKeyId': None}}, 'RoleArn': 'arn:aws:iam::138066269299:role/TeamRole', 'StoppingCondition': {'MaxRuntimeInSeconds': 3600}}
# 2020-10-29 21:12:04,943 - __main__ - INFO - Current Environment:{'dataset_format': '{"csv": {"header": false, "output_columns_position": "START"}}', 'dataset_source': '/opt/ml/processing/input/baseline_dataset_input', 'output_path': '/opt/ml/processing/output', 'publish_cloudwatch_metrics': 'Disabled'}
# 2020-10-29 21:12:04,943 - DefaultDataAnalyzer - INFO - Performing analysis with input: {"dataset_source": "/opt/ml/processing/input/baseline_dataset_input", "dataset_format": {"csv": {"header": false, "output_columns_position": "START"}}, "record_preprocessor_script": null, "post_analytics_processor_script": null, "baseline_constraints": null, "baseline_statistics": null, "output_path": "/opt/ml/processing/output", "start_time": null, "end_time": null, "cloudwatch_metrics_directory": "/opt/ml/output/metrics/cloudwatch", "publish_cloudwatch_metrics": "Disabled", "sagemaker_endpoint_name": null, "sagemaker_monitoring_schedule_name": null, "output_message_file": "/opt/ml/output/message"}
# 2020-10-29 21:12:04,943 - DefaultDataAnalyzer - INFO - Bootstrapping yarn
# 2020-10-29 21:12:04,943 - bootstrap - INFO - Copy aws jars
# 2020-10-29 21:12:05,001 - bootstrap - INFO - Copy cluster config
# 2020-10-29 21:12:05,002 - bootstrap - INFO - Write runtime cluster config
# 2020-10-29 21:12:05,002 - bootstrap - INFO - Resource Config is: {'current_host': 'algo-1', 'hosts': ['algo-1']}
# 2020-10-29 21:12:05,010 - bootstrap - INFO - Finished Yarn configuration files setup.
# 2020-10-29 21:12:05,011 - bootstrap - INFO - Starting spark process for master node algo-1
# 2020-10-29 21:12:05,011 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs namenode -format -force
# WARNING: /usr/hadoop-3.0.0/logs does not exist. Creating.
# 2020-10-29 21:12:05,481 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = algo-1/10.0.167.100
# STARTUP_MSG:   args = [-format, -force]
# STARTUP_MSG:   version = 3.0.0
# STARTUP_MSG:   classpath = /usr/hadoop-3.0.0/etc/hadoop:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-servlet-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-io-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/netty-3.10.5.Final.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/avro-1.7.7.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-admin-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jersey-server-1.19.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/httpcore-4.4.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsr305-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-lang-2.6.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/re2j-1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-util-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-mapper-asl-1.9.13.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/mockito-all-1.8.5.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-identity-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-config-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-io-2.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-xml-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-lang3-3.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/protobuf-java-2.5.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/curator-recipes-2.12.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jul-to-slf4j-1.7.25.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-server-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-xdr-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-codec-1.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-server-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-webapp-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsp-api-2.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/token-provider-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/accessors-smart-1.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-pkix-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/paranamer-2.3.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/hadoop-annotations-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-util-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/gson-2.2.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-simplekdc-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-collections-3.2.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-net-3.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jersey-json-1.19.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-math3-3.1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jaxb-api-2.2.11.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerby-asn1-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jersey-servlet-1.19.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jettison-1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jcip-annotations-1.0-1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/commons-cli-1.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/kerb-core-1.0.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-util-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/asm-5.0.4.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/junit-4.11.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/curator-client-2.12.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/woodstox-core-5.0.3.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/hadoop-auth-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jackson-xc-1.9.13.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/xz-1.0.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jetty-http-9.3.19.v20170502.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/httpclient-4.5.2.jar:/usr/hadoop-3.0.0/share/hadoop/common/lib/jsch-0.1.54.ja ...
# -3.0.0/share/hadoop/yarn/hadoop-yarn-server-resourcemanager-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-common-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-sharedcachemanager-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-router-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-api-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-timelineservice-hbase-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-registry-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-web-proxy-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-applicationhistoryservice-3.0.0.jar:/usr/hadoop-3.0.0/share/hadoop/yarn/hadoop-yarn-server-timelineservice-3.0.0.jar
# STARTUP_MSG:   build = https://git-wip-us.apache.org/repos/asf/hadoop.git -r c25427ceca461ee979d30edd7a4b0f50718e6533; compiled by 'andrew' on 2017-12-08T19:16Z
# STARTUP_MSG:   java = 1.8.0_265
# ************************************************************/
# 2020-10-29 21:12:05,490 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2020-10-29 21:12:05,494 INFO namenode.NameNode: createNameNode [-format, -force]
# Formatting using clusterid: CID-9ab0aea7-c7e9-489f-b712-91c697edf3e6
# 2020-10-29 21:12:05,987 INFO namenode.FSEditLog: Edit logging is async:true
# 2020-10-29 21:12:05,998 INFO namenode.FSNamesystem: KeyProvider: null
# 2020-10-29 21:12:05,999 INFO namenode.FSNamesystem: fsLock is fair: true
# 2020-10-29 21:12:06,000 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2020-10-29 21:12:06,005 INFO namenode.FSNamesystem: fsOwner             = root (auth:SIMPLE)
# 2020-10-29 21:12:06,005 INFO namenode.FSNamesystem: supergroup          = supergroup
# 2020-10-29 21:12:06,005 INFO namenode.FSNamesystem: isPermissionEnabled = true
# 2020-10-29 21:12:06,005 INFO namenode.FSNamesystem: HA Enabled: false
# 2020-10-29 21:12:06,037 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2020-10-29 21:12:06,052 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit: configured=1000, counted=60, effected=1000
# 2020-10-29 21:12:06,052 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2020-10-29 21:12:06,056 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2020-10-29 21:12:06,056 INFO blockmanagement.BlockManager: The block deletion will start around 2020 Oct 29 21:12:06
# 2020-10-29 21:12:06,057 INFO util.GSet: Computing capacity for map BlocksMap
# 2020-10-29 21:12:06,057 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 21:12:06,059 INFO util.GSet: 2.0% max memory 3.1 GB = 64.3 MB
# 2020-10-29 21:12:06,059 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2020-10-29 21:12:06,093 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2020-10-29 21:12:06,097 INFO Configuration.deprecation: No unit for dfs.namenode.safemode.extension(30000) assuming MILLISECONDS
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.9990000128746033
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: minReplication             = 1
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2020-10-29 21:12:06,097 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2020-10-29 21:12:06,127 INFO util.GSet: Computing capacity for map INodeMap
# 2020-10-29 21:12:06,127 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 21:12:06,127 INFO util.GSet: 1.0% max memory 3.1 GB = 32.1 MB
# 2020-10-29 21:12:06,127 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2020-10-29 21:12:06,129 INFO namenode.FSDirectory: ACLs enabled? false
# 2020-10-29 21:12:06,129 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2020-10-29 21:12:06,129 INFO namenode.FSDirectory: XAttrs enabled? true
# 2020-10-29 21:12:06,129 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2020-10-29 21:12:06,133 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true
# 2020-10-29 21:12:06,136 INFO util.GSet: Computing capacity for map cachedBlocks
# 2020-10-29 21:12:06,137 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 21:12:06,137 INFO util.GSet: 0.25% max memory 3.1 GB = 8.0 MB
# 2020-10-29 21:12:06,137 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2020-10-29 21:12:06,176 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2020-10-29 21:12:06,176 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2020-10-29 21:12:06,176 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2020-10-29 21:12:06,179 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2020-10-29 21:12:06,179 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2020-10-29 21:12:06,181 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2020-10-29 21:12:06,181 INFO util.GSet: VM type       = 64-bit
# 2020-10-29 21:12:06,181 INFO util.GSet: 0.029999999329447746% max memory 3.1 GB = 986.9 KB
# 2020-10-29 21:12:06,181 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2020-10-29 21:12:06,201 INFO namenode.FSImage: Allocated new BlockPoolId: BP-304081958-10.0.167.100-1604005926196
# 2020-10-29 21:12:06,213 INFO common.Storage: Storage directory /opt/amazon/hadoop/hdfs/namenode has been successfully formatted.
# 2020-10-29 21:12:06,220 INFO namenode.FSImageFormatProtobuf: Saving image file /opt/amazon/hadoop/hdfs/namenode/current/fsimage.ckpt_0000000000000000000 using no compression
# 2020-10-29 21:12:06,293 INFO namenode.FSImageFormatProtobuf: Image file /opt/amazon/hadoop/hdfs/namenode/current/fsimage.ckpt_0000000000000000000 of size 389 bytes saved in 0 seconds.
# 2020-10-29 21:12:06,304 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2020-10-29 21:12:06,307 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at algo-1/10.0.167.100
# ************************************************************/
# 2020-10-29 21:12:06,318 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs --daemon start namenode
# 2020-10-29 21:12:08,365 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/hdfs --daemon start namenode, return code 1
# 2020-10-29 21:12:08,365 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/hdfs --daemon start datanode
# 2020-10-29 21:12:10,425 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/hdfs --daemon start datanode, return code 1
# 2020-10-29 21:12:10,426 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start resourcemanager
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# WARNING: /var/log/yarn/ does not exist. Creating.
# 2020-10-29 21:12:12,510 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start resourcemanager, return code 1
# 2020-10-29 21:12:12,510 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start nodemanager
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# 2020-10-29 21:12:14,591 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start nodemanager, return code 1
# 2020-10-29 21:12:14,592 - bootstrap - INFO - Running command: /usr/hadoop-3.0.0/bin/yarn --daemon start proxyserver
# WARNING: YARN_LOG_DIR has been replaced by HADOOP_LOG_DIR. Using value of YARN_LOG_DIR.
# 2020-10-29 21:12:16,686 - bootstrap - INFO - Failed to run /usr/hadoop-3.0.0/bin/yarn --daemon start proxyserver, return code 1
# 2020-10-29 21:12:16,686 - DefaultDataAnalyzer - INFO - Total number of hosts in the cluster: 1
# 2020-10-29 21:12:26,694 - DefaultDataAnalyzer - INFO - Running command: bin/spark-submit --master yarn --deploy-mode client --conf spark.hadoop.fs.s3a.aws.credentials.provider=org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider --conf spark.serializer=org.apache.spark.serializer.KryoSerializer /opt/amazon/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar --analytics_input /tmp/spark_job_config.json
# 2020-10-29 21:12:27 WARN  NativeCodeLoader:60 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2020-10-29 21:12:27 INFO  Main:27 - Start analyzing with args: --analytics_input /tmp/spark_job_config.json
# 2020-10-29 21:12:27 INFO  Main:30 - Analytics input path: DataAnalyzerParams(/tmp/spark_job_config.json,yarn)
# 2020-10-29 21:12:27 INFO  FileUtil:66 - Read file from path /tmp/spark_job_config.json.
# 2020-10-29 21:12:28 INFO  SparkContext:54 - Running Spark version 2.3.1
# 2020-10-29 21:12:28 INFO  SparkContext:54 - Submitted application: SageMakerDataAnalyzer
# 2020-10-29 21:12:28 INFO  SecurityManager:54 - Changing view acls to: root
# 2020-10-29 21:12:28 INFO  SecurityManager:54 - Changing modify acls to: root
# 2020-10-29 21:12:28 INFO  SecurityManager:54 - Changing view acls groups to:
# 2020-10-29 21:12:28 INFO  SecurityManager:54 - Changing modify acls groups to:
# 2020-10-29 21:12:28 INFO  SecurityManager:54 - SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 2020-10-29 21:12:28 INFO  Utils:54 - Successfully started service 'sparkDriver' on port 41025.
# 2020-10-29 21:12:28 INFO  SparkEnv:54 - Registering MapOutputTracker
# 2020-10-29 21:12:28 INFO  SparkEnv:54 - Registering BlockManagerMaster
# 2020-10-29 21:12:28 INFO  BlockManagerMasterEndpoint:54 - Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 2020-10-29 21:12:28 INFO  BlockManagerMasterEndpoint:54 - BlockManagerMasterEndpoint up
# 2020-10-29 21:12:28 INFO  DiskBlockManager:54 - Created local directory at /tmp/blockmgr-664ab203-d739-4552-8121-9622e7a8108c
# 2020-10-29 21:12:28 INFO  MemoryStore:54 - MemoryStore started with capacity 1458.6 MB
# 2020-10-29 21:12:28 INFO  SparkEnv:54 - Registering OutputCommitCoordinator
# 2020-10-29 21:12:28 INFO  SparkContext:54 - Added JAR file:/opt/amazon/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar at spark://10.0.167.100:41025/jars/sagemaker-data-analyzer-1.0-jar-with-dependencies.jar with timestamp 1604005948727
# 2020-10-29 21:12:29 INFO  RMProxy:133 - Connecting to ResourceManager at /10.0.167.100:8032
# 2020-10-29 21:12:29 INFO  Client:54 - Requesting a new application from cluster with 1 NodeManagers
# 2020-10-29 21:12:29 INFO  Configuration:2636 - resource-types.xml not found
# 2020-10-29 21:12:29 INFO  ResourceUtils:427 - Unable to find 'resource-types.xml'.
# 2020-10-29 21:12:29 INFO  Client:54 - Verifying our application has not requested more than the maximum memory capability of the cluster (15746 MB per container)
# 2020-10-29 21:12:29 INFO  Client:54 - Will allocate AM container, with 896 MB memory including 384 MB overhead
# 2020-10-29 21:12:29 INFO  Client:54 - Setting up container launch context for our AM
# 2020-10-29 21:12:29 INFO  Client:54 - Setting up the launch environment for our AM container
# 2020-10-29 21:12:29 INFO  Client:54 - Preparing resources for our AM container
# 2020-10-29 21:12:30 WARN  Client:66 - Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2020-10-29 21:12:32 INFO  Client:54 - Uploading resource file:/tmp/spark-5b09af90-1733-4778-82ba-fa6770823436/__spark_libs__7373651296796360345.zip -> hdfs://10.0.167.100/user/root/.sparkStaging/application_1604005931950_0001/__spark_libs__7373651296796360345.zip
# 2020-10-29 21:12:33 INFO  Client:54 - Uploading resource file:/tmp/spark-5b09af90-1733-4778-82ba-fa6770823436/__spark_conf__3030490333987780236.zip -> hdfs://10.0.167.100/user/root/.sparkStaging/application_1604005931950_0001/__spark_conf__.zip
# 2020-10-29 21:12:33 INFO  SecurityManager:54 - Changing view acls to: root
# 2020-10-29 21:12:33 INFO  SecurityManager:54 - Changing modify acls to: root
# 2020-10-29 21:12:33 INFO  SecurityManager:54 - Changing view acls groups to:
# 2020-10-29 21:12:33 INFO  SecurityManager:54 - Changing modify acls groups to:
# 2020-10-29 21:12:33 INFO  SecurityManager:54 - SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 2020-10-29 21:12:33 INFO  Client:54 - Submitting application application_1604005931950_0001 to ResourceManager
# 2020-10-29 21:12:34 INFO  YarnClientImpl:310 - Submitted application application_1604005931950_0001
# 2020-10-29 21:12:34 INFO  SchedulerExtensionServices:54 - Starting Yarn extension services with app application_1604005931950_0001 and attemptId None
# 2020-10-29 21:12:35 INFO  Client:54 - Application report for application_1604005931950_0001 (state: ACCEPTED)
# 2020-10-29 21:12:35 INFO  Client:54 -
# #011 client token: N/A
# #011 diagnostics: [Thu Oct 29 21:12:34 +0000 2020] Scheduler has assigned a container for AM, waiting for AM container to be launched
# #011 ApplicationMaster host: N/A
# #011 ApplicationMaster RPC port: -1
# #011 queue: default
# #011 start time: 1604005954005
# #011 final status: UNDEFINED
# #011 tracking URL: http://algo-1:8088/proxy/application_1604005931950_0001/
# #011 user: root
# 2020-10-29 21:12:36 INFO  Client:54 - Application report for application_1604005931950_0001 (state: ACCEPTED)
# 2020-10-29 21:12:37 INFO  Client:54 - Application report for application_1604005931950_0001 (state: ACCEPTED)
# 2020-10-29 21:12:38 INFO  Client:54 - Application report for application_1604005931950_0001 (state: ACCEPTED)
# 2020-10-29 21:12:39 INFO  Client:54 - Application report for application_1604005931950_0001 (state: ACCEPTED)
# 2020-10-29 21:12:39 INFO  YarnClientSchedulerBackend:54 - Add WebUI Filter. org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter, Map(PROXY_HOSTS -> algo-1, PROXY_URI_BASES -> http://algo-1:8088/proxy/application_1604005931950_0001), /proxy/application_1604005931950_0001
# 2020-10-29 21:12:39 INFO  YarnSchedulerBackend$YarnSchedulerEndpoint:54 - ApplicationMaster registered as NettyRpcEndpointRef(spark-client://YarnAM)
# 2020-10-29 21:12:40 INFO  Client:54 - Application report for application_1604005931950_0001 (state: RUNNING)
# 2020-10-29 21:12:40 INFO  Client:54 -
# #011 client token: N/A
# #011 diagnostics: N/A
# #011 ApplicationMaster host: 10.0.167.100
# #011 ApplicationMaster RPC port: 0
# #011 queue: default
# #011 start time: 1604005954005
# #011 final status: UNDEFINED
# #011 tracking URL: http://algo-1:8088/proxy/application_1604005931950_0001/
# #011 user: root
# 2020-10-29 21:12:40 INFO  YarnClientSchedulerBackend:54 - Application application_1604005931950_0001 has started running.
# 2020-10-29 21:12:40 INFO  Utils:54 - Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 39949.
# 2020-10-29 21:12:40 INFO  NettyBlockTransferService:54 - Server created on 10.0.167.100:39949
# 2020-10-29 21:12:40 INFO  BlockManager:54 - Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 2020-10-29 21:12:40 INFO  BlockManagerMaster:54 - Registering BlockManager BlockManagerId(driver, 10.0.167.100, 39949, None)
# 2020-10-29 21:12:40 INFO  BlockManagerMasterEndpoint:54 - Registering block manager 10.0.167.100:39949 with 1458.6 MB RAM, BlockManagerId(driver, 10.0.167.100, 39949, None)
# 2020-10-29 21:12:40 INFO  BlockManagerMaster:54 - Registered BlockManager BlockManagerId(driver, 10.0.167.100, 39949, None)
# 2020-10-29 21:12:40 INFO  BlockManager:54 - Initialized BlockManager: BlockManagerId(driver, 10.0.167.100, 39949, None)
# 2020-10-29 21:12:40 INFO  log:192 - Logging initialized @13404ms
# 2020-10-29 21:12:42 INFO  YarnSchedulerBackend$YarnDriverEndpoint:54 - Registered executor NettyRpcEndpointRef(spark-client://Executor) (10.0.167.100:51538) with ID 1
# 2020-10-29 21:12:42 INFO  BlockManagerMasterEndpoint:54 - Registering block manager algo-1:43127 with 5.8 GB RAM, BlockManagerId(1, algo-1, 43127, None)
# 2020-10-29 21:12:58 INFO  YarnClientSchedulerBackend:54 - SchedulerBackend is ready for scheduling beginning after waiting maxRegisteredResourcesWaitingTime: 30000(ms)
# 2020-10-29 21:12:58 WARN  SparkContext:66 - Spark is not running in local mode, therefore the checkpoint directory must not be on the local filesystem. Directory '/tmp' appears to be on the local filesystem.
# 2020-10-29 21:12:59 INFO  DatasetReader:90 - Files to process:List(file:///opt/ml/processing/input/baseline_dataset_input/train_set.csv)
# 2020-10-29 21:12:59 INFO  SharedState:54 - Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir ('file:/usr/spark-2.3.1/spark-warehouse').
# 2020-10-29 21:12:59 INFO  SharedState:54 - Warehouse path is 'file:/usr/spark-2.3.1/spark-warehouse'.
# 2020-10-29 21:12:59 INFO  StateStoreCoordinatorRef:54 - Registered StateStoreCoordinator endpoint
# 2020-10-29 21:13:00 INFO  FileSourceStrategy:54 - Pruning directories with:
# 2020-10-29 21:13:00 INFO  FileSourceStrategy:54 - Post-Scan Filters: (length(trim(value#0, None)) > 0)
# 2020-10-29 21:13:00 INFO  FileSourceStrategy:54 - Output Data Schema: struct<value: string>
# 2020-10-29 21:13:00 INFO  FileSourceScanExec:54 - Pushed Filters:
# 2020-10-29 21:13:00 INFO  CodeGenerator:54 - Code generated in 184.914613 ms
# 2020-10-29 21:13:00 INFO  CodeGenerator:54 - Code generated in 21.261592 ms
# 2020-10-29 21:13:00 INFO  MemoryStore:54 - Block broadcast_0 stored as values in memory (estimated size 429.5 KB, free 1458.2 MB)
# 2020-10-29 21:13:00 INFO  MemoryStore:54 - Block broadcast_0_piece0 stored as bytes in memory (estimated size 38.2 KB, free 1458.1 MB)
# 2020-10-29 21:13:00 INFO  BlockManagerInfo:54 - Added broadcast_0_piece0 in memory on 10.0.167.100:39949 (size: 38.2 KB, free: 1458.6 MB)
# 2020-10-29 21:13:00 INFO  SparkContext:54 - Created broadcast 0 from csv at DatasetReader.scala:49
# 2020-10-29 21:13:00 INFO  FileSourceScanExec:54 - Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 2020-10-29 21:13:00 INFO  SparkContext:54 - Starting job: csv at DatasetReader.scala:49
# 2020-10-29 21:13:00 INFO  DAGScheduler:54 - Got job 0 (csv at DatasetReader.scala:49) with 1 output partitions
# 2020-10-29 21:13:00 INFO  DAGScheduler:54 - Final stage: ResultStage 0 (csv at DatasetReader.scala:49)
# 2020-10-29 21:13:00 INFO  DAGScheduler:54 - Parents of final stage: List()
# 2020-10-29 21:13:00 INFO  DAGScheduler:54 - Missing parents: List()
# 2020-10-29 21:13:00 INFO  DAGScheduler:54 - Submitting ResultStage 0 (MapPartitionsRDD[3] at csv at DatasetReader.scala:49), which has no missing parents
# 2020-10-29 21:13:01 INFO  MemoryStore:54 - Block broadcast_1 stored as values in memory (estimated size 9.4 KB, free 1458.1 MB)
# 2020-10-29 21:13:01 INFO  MemoryStore:54 - Block broadcast_1_piece0 stored as bytes in memory (estimated size 4.5 KB, free 1458.1 MB)
# 2020-10-29 21:13:01 INFO  BlockManagerInfo:54 - Added broadcast_1_piece0 in memory on 10.0.167.100:39949 (size: 4.5 KB, free: 1458.6 MB)
# 2020-10-29 21:13:01 INFO  SparkContext:54 - Created broadcast 1 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:01 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[3] at csv at DatasetReader.scala:49) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:01 INFO  YarnScheduler:54 - Adding task set 0.0 with 1 tasks
# 2020-10-29 21:13:01 INFO  TaskSetManager:54 - Starting task 0.0 in stage 0.0 (TID 0, algo-1, executor 1, partition 0, PROCESS_LOCAL, 8344 bytes)
# 2020-10-29 21:13:02 INFO  BlockManagerInfo:54 - Added broadcast_1_piece0 in memory on algo-1:43127 (size: 4.5 KB, free: 5.8 GB)
# 2020-10-29 21:13:02 INFO  BlockManagerInfo:54 - Added broadcast_0_piece0 in memory on algo-1:43127 (size: 38.2 KB, free: 5.8 GB)
# 2020-10-29 21:13:02 INFO  TaskSetManager:54 - Finished task 0.0 in stage 0.0 (TID 0) in 1866 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:02 INFO  YarnScheduler:54 - Removed TaskSet 0.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:02 INFO  DAGScheduler:54 - ResultStage 0 (csv at DatasetReader.scala:49) finished in 1.954 s
# 2020-10-29 21:13:02 INFO  DAGScheduler:54 - Job 0 finished: csv at DatasetReader.scala:49, took 1.995561 s
# 2020-10-29 21:13:02 INFO  FileSourceStrategy:54 - Pruning directories with:
# 2020-10-29 21:13:02 INFO  FileSourceStrategy:54 - Post-Scan Filters:
# 2020-10-29 21:13:02 INFO  FileSourceStrategy:54 - Output Data Schema: struct<value: string>
# 2020-10-29 21:13:02 INFO  FileSourceScanExec:54 - Pushed Filters:
# 2020-10-29 21:13:02 INFO  CodeGenerator:54 - Code generated in 7.887358 ms
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_2 stored as values in memory (estimated size 429.5 KB, free 1457.7 MB)
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_2_piece0 stored as bytes in memory (estimated size 38.2 KB, free 1457.7 MB)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added broadcast_2_piece0 in memory on 10.0.167.100:39949 (size: 38.2 KB, free: 1458.5 MB)
# 2020-10-29 21:13:03 INFO  SparkContext:54 - Created broadcast 2 from csv at DatasetReader.scala:49
# 2020-10-29 21:13:03 INFO  FileSourceScanExec:54 - Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 2020-10-29 21:13:03 INFO  FileSourceStrategy:54 - Pruning directories with:
# 2020-10-29 21:13:03 INFO  FileSourceStrategy:54 - Post-Scan Filters:
# 2020-10-29 21:13:03 INFO  FileSourceStrategy:54 - Output Data Schema: struct<_c0: string, _c1: string, _c2: string, _c3: string, _c4: string ... 29 more fields>
# 2020-10-29 21:13:03 INFO  FileSourceScanExec:54 - Pushed Filters:
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_3 stored as values in memory (estimated size 429.5 KB, free 1457.3 MB)
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_3_piece0 stored as bytes in memory (estimated size 38.2 KB, free 1457.2 MB)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added broadcast_3_piece0 in memory on 10.0.167.100:39949 (size: 38.2 KB, free: 1458.5 MB)
# 2020-10-29 21:13:03 INFO  SparkContext:54 - Created broadcast 3 from cache at DataAnalyzer.scala:76
# 2020-10-29 21:13:03 INFO  FileSourceScanExec:54 - Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 2020-10-29 21:13:03 WARN  Utils:66 - Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.debug.maxToStringFields' in SparkEnv.conf.
# 2020-10-29 21:13:03 INFO  CodeGenerator:54 - Code generated in 55.708794 ms
# 2020-10-29 21:13:03 INFO  CodeGenerator:54 - Code generated in 36.425325 ms
# 2020-10-29 21:13:03 INFO  SparkContext:54 - Starting job: head at DataAnalyzer.scala:79
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Got job 1 (head at DataAnalyzer.scala:79) with 1 output partitions
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Final stage: ResultStage 1 (head at DataAnalyzer.scala:79)
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Parents of final stage: List()
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Missing parents: List()
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Submitting ResultStage 1 (MapPartitionsRDD[17] at head at DataAnalyzer.scala:79), which has no missing parents
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_4 stored as values in memory (estimated size 45.5 KB, free 1457.2 MB)
# 2020-10-29 21:13:03 INFO  MemoryStore:54 - Block broadcast_4_piece0 stored as bytes in memory (estimated size 16.7 KB, free 1457.2 MB)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added broadcast_4_piece0 in memory on 10.0.167.100:39949 (size: 16.7 KB, free: 1458.5 MB)
# 2020-10-29 21:13:03 INFO  SparkContext:54 - Created broadcast 4 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ResultStage 1 (MapPartitionsRDD[17] at head at DataAnalyzer.scala:79) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:03 INFO  YarnScheduler:54 - Adding task set 1.0 with 1 tasks
# 2020-10-29 21:13:03 INFO  TaskSetManager:54 - Starting task 0.0 in stage 1.0 (TID 1, algo-1, executor 1, partition 0, PROCESS_LOCAL, 8344 bytes)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added broadcast_4_piece0 in memory on algo-1:43127 (size: 16.7 KB, free: 5.8 GB)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added broadcast_3_piece0 in memory on algo-1:43127 (size: 38.2 KB, free: 5.8 GB)
# 2020-10-29 21:13:03 INFO  BlockManagerInfo:54 - Added rdd_11_0 in memory on algo-1:43127 (size: 142.4 KB, free: 5.8 GB)
# 2020-10-29 21:13:03 INFO  TaskSetManager:54 - Finished task 0.0 in stage 1.0 (TID 1) in 528 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - ResultStage 1 (head at DataAnalyzer.scala:79) finished in 0.577 s
# 2020-10-29 21:13:03 INFO  DAGScheduler:54 - Job 1 finished: head at DataAnalyzer.scala:79, took 0.583704 s
# 2020-10-29 21:13:03 INFO  YarnScheduler:54 - Removed TaskSet 1.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:04 INFO  CodeGenerator:54 - Code generated in 45.824843 ms
# 2020-10-29 21:13:04 INFO  SparkContext:54 - Starting job: collect at AnalysisRunner.scala:313
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Registering RDD 22 (collect at AnalysisRunner.scala:313)
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Got job 2 (collect at AnalysisRunner.scala:313) with 1 output partitions
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Final stage: ResultStage 3 (collect at AnalysisRunner.scala:313)
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Parents of final stage: List(ShuffleMapStage 2)
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Missing parents: List(ShuffleMapStage 2)
# 2020-10-29 21:13:04 INFO  DAGScheduler:54 - Submitting ShuffleMapStage 2 (MapPartitionsRDD[22] at collect at AnalysisRunner.scala:313), which has no missing parents
# 2020-10-29 21:13:04 INFO  MemoryStore:54 - Block broadcast_5 stored as values in memory (estimated size 299.5 KB, free 1456.9 MB)
# 2020-10-29 21:13:04 INFO  MemoryStore:54 - Block broadcast_5_piece0 stored as bytes in memory (estimated size 94.2 KB, free 1456.8 MB)
# 2020-10-29 21:13:05 INFO  BlockManagerInfo:54 - Added broadcast_5_piece0 in memory on 10.0.167.100:39949 (size: 94.2 KB, free: 1458.4 MB)
# 2020-10-29 21:13:05 INFO  SparkContext:54 - Created broadcast 5 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:05 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ShuffleMapStage 2 (MapPartitionsRDD[22] at collect at AnalysisRunner.scala:313) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:05 INFO  YarnScheduler:54 - Adding task set 2.0 with 1 tasks
# 2020-10-29 21:13:05 INFO  TaskSetManager:54 - Starting task 0.0 in stage 2.0 (TID 2, algo-1, executor 1, partition 0, PROCESS_LOCAL, 8333 bytes)
# 2020-10-29 21:13:05 INFO  BlockManagerInfo:54 - Added broadcast_5_piece0 in memory on algo-1:43127 (size: 94.2 KB, free: 5.8 GB)
# 2020-10-29 21:13:06 INFO  TaskSetManager:54 - Finished task 0.0 in stage 2.0 (TID 2) in 1827 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:06 INFO  YarnScheduler:54 - Removed TaskSet 2.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - ShuffleMapStage 2 (collect at AnalysisRunner.scala:313) finished in 1.869 s
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - looking for newly runnable stages
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - running: Set()
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - waiting: Set(ResultStage 3)
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - failed: Set()
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - Submitting ResultStage 3 (MapPartitionsRDD[25] at collect at AnalysisRunner.scala:313), which has no missing parents
# 2020-10-29 21:13:06 INFO  MemoryStore:54 - Block broadcast_6 stored as values in memory (estimated size 364.6 KB, free 1456.4 MB)
# 2020-10-29 21:13:06 INFO  MemoryStore:54 - Block broadcast_6_piece0 stored as bytes in memory (estimated size 106.6 KB, free 1456.3 MB)
# 2020-10-29 21:13:06 INFO  BlockManagerInfo:54 - Added broadcast_6_piece0 in memory on 10.0.167.100:39949 (size: 106.6 KB, free: 1458.3 MB)
# 2020-10-29 21:13:06 INFO  SparkContext:54 - Created broadcast 6 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:06 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ResultStage 3 (MapPartitionsRDD[25] at collect at AnalysisRunner.scala:313) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:06 INFO  YarnScheduler:54 - Adding task set 3.0 with 1 tasks
# 2020-10-29 21:13:06 INFO  TaskSetManager:54 - Starting task 0.0 in stage 3.0 (TID 3, algo-1, executor 1, partition 0, NODE_LOCAL, 7765 bytes)
# 2020-10-29 21:13:06 INFO  BlockManagerInfo:54 - Added broadcast_6_piece0 in memory on algo-1:43127 (size: 106.6 KB, free: 5.8 GB)
# 2020-10-29 21:13:06 INFO  MapOutputTrackerMasterEndpoint:54 - Asked to send map output locations for shuffle 0 to 10.0.167.100:51538
# 2020-10-29 21:13:07 INFO  TaskSetManager:54 - Finished task 0.0 in stage 3.0 (TID 3) in 748 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:07 INFO  YarnScheduler:54 - Removed TaskSet 3.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - ResultStage 3 (collect at AnalysisRunner.scala:313) finished in 0.789 s
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Job 2 finished: collect at AnalysisRunner.scala:313, took 2.684206 s
# 2020-10-29 21:13:07 INFO  SparkContext:54 - Starting job: countByKey at ColumnProfiler.scala:566
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Registering RDD 32 (countByKey at ColumnProfiler.scala:566)
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Got job 3 (countByKey at ColumnProfiler.scala:566) with 1 output partitions
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Final stage: ResultStage 5 (countByKey at ColumnProfiler.scala:566)
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Parents of final stage: List(ShuffleMapStage 4)
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Missing parents: List(ShuffleMapStage 4)
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Submitting ShuffleMapStage 4 (MapPartitionsRDD[32] at countByKey at ColumnProfiler.scala:566), which has no missing parents
# 2020-10-29 21:13:07 INFO  MemoryStore:54 - Block broadcast_7 stored as values in memory (estimated size 38.2 KB, free 1456.3 MB)
# 2020-10-29 21:13:07 INFO  MemoryStore:54 - Block broadcast_7_piece0 stored as bytes in memory (estimated size 16.4 KB, free 1456.3 MB)
# 2020-10-29 21:13:07 INFO  BlockManagerInfo:54 - Added broadcast_7_piece0 in memory on 10.0.167.100:39949 (size: 16.4 KB, free: 1458.3 MB)
# 2020-10-29 21:13:07 INFO  SparkContext:54 - Created broadcast 7 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:07 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ShuffleMapStage 4 (MapPartitionsRDD[32] at countByKey at ColumnProfiler.scala:566) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:07 INFO  YarnScheduler:54 - Adding task set 4.0 with 1 tasks
# 2020-10-29 21:13:07 INFO  TaskSetManager:54 - Starting task 0.0 in stage 4.0 (TID 4, algo-1, executor 1, partition 0, PROCESS_LOCAL, 8333 bytes)
# 2020-10-29 21:13:07 INFO  BlockManagerInfo:54 - Added broadcast_7_piece0 in memory on algo-1:43127 (size: 16.4 KB, free: 5.8 GB)
# 2020-10-29 21:13:08 INFO  TaskSetManager:54 - Finished task 0.0 in stage 4.0 (TID 4) in 977 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:08 INFO  YarnScheduler:54 - Removed TaskSet 4.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - ShuffleMapStage 4 (countByKey at ColumnProfiler.scala:566) finished in 1.018 s
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - looking for newly runnable stages
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - running: Set()
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - waiting: Set(ResultStage 5)
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - failed: Set()
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - Submitting ResultStage 5 (ShuffledRDD[33] at countByKey at ColumnProfiler.scala:566), which has no missing parents
# 2020-10-29 21:13:08 INFO  MemoryStore:54 - Block broadcast_8 stored as values in memory (estimated size 3.2 KB, free 1456.3 MB)
# 2020-10-29 21:13:08 INFO  MemoryStore:54 - Block broadcast_8_piece0 stored as bytes in memory (estimated size 1919.0 B, free 1456.3 MB)
# 2020-10-29 21:13:08 INFO  BlockManagerInfo:54 - Added broadcast_8_piece0 in memory on 10.0.167.100:39949 (size: 1919.0 B, free: 1458.3 MB)
# 2020-10-29 21:13:08 INFO  SparkContext:54 - Created broadcast 8 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ResultStage 5 (ShuffledRDD[33] at countByKey at ColumnProfiler.scala:566) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:08 INFO  YarnScheduler:54 - Adding task set 5.0 with 1 tasks
# 2020-10-29 21:13:08 INFO  TaskSetManager:54 - Starting task 0.0 in stage 5.0 (TID 5, algo-1, executor 1, partition 0, NODE_LOCAL, 7660 bytes)
# 2020-10-29 21:13:08 INFO  BlockManagerInfo:54 - Added broadcast_8_piece0 in memory on algo-1:43127 (size: 1919.0 B, free: 5.8 GB)
# 2020-10-29 21:13:08 INFO  MapOutputTrackerMasterEndpoint:54 - Asked to send map output locations for shuffle 1 to 10.0.167.100:51538
# 2020-10-29 21:13:08 INFO  TaskSetManager:54 - Finished task 0.0 in stage 5.0 (TID 5) in 45 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:08 INFO  YarnScheduler:54 - Removed TaskSet 5.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - ResultStage 5 (countByKey at ColumnProfiler.scala:566) finished in 0.060 s
# 2020-10-29 21:13:08 INFO  DAGScheduler:54 - Job 3 finished: countByKey at ColumnProfiler.scala:566, took 1.093478 s
# 2020-10-29 21:13:08 INFO  ConstraintGenerator:45 - Generating Constraints:
# 2020-10-29 21:13:08 INFO  ContextCleaner:54 - Cleaned accumulator 172
# 2020-10-29 21:13:08 INFO  ContextCleaner:54 - Cleaned accumulator 94
# 2020-10-29 21:13:08 INFO  ContextCleaner:54 - Cleaned accumulator 49
# 2020-10-29 21:13:08 INFO  ContextCleaner:54 - Cleaned accumulator 8
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned shuffle 0
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 132
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 31
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 156
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 157
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 152
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 2
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 117
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 68
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 69
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 82
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 100
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 47
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 29
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 168
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 147
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 71
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_5_piece0 on 10.0.167.100:39949 in memory (size: 94.2 KB, free: 1458.3 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_5_piece0 on algo-1:43127 in memory (size: 94.2 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 141
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_1_piece0 on 10.0.167.100:39949 in memory (size: 4.5 KB, free: 1458.3 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_1_piece0 on algo-1:43127 in memory (size: 4.5 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 44
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_0_piece0 on 10.0.167.100:39949 in memory (size: 38.2 KB, free: 1458.4 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_0_piece0 on algo-1:43127 in memory (size: 38.2 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 87
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 73
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 158
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 102
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 45
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 32
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 55
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_6_piece0 on 10.0.167.100:39949 in memory (size: 106.6 KB, free: 1458.5 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_6_piece0 on algo-1:43127 in memory (size: 106.6 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 173
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 42
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 95
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 177
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 179
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 72
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 108
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 10
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 96
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 112
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 64
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 175
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 23
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 140
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 143
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 164
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_7_piece0 on 10.0.167.100:39949 in memory (size: 16.4 KB, free: 1458.5 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Removed broadcast_7_piece0 on algo-1:43127 in memory (size: 16.4 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 170
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 144
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 52
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 165
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 106
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 120
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 101
# 2020-10-29 21:13:09 INFO  ContextCleaner:54 - Cleaned accumulator 90
# ...
#     "completeness" : 1.0
#   }, {
#     "name" : "_c2",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c3",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c4",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c5",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c6",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c7",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c8",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c9",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c10",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c11",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c12",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c13",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c14",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c15",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c16",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c17",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c18",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c19",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c20",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c21",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c22",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c23",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c24",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c25",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c26",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c27",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c28",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c29",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   }, {
#     "name" : "_c30",
#     "inferred_type" : "String",
#     "completeness" : 1.0
#   } ],
#   "monitoring_config" : {
#     "evaluate_constraints" : "Enabled",
#     "emit_metrics" : "Enabled",
#     "datatype_check_threshold" : 1.0,
#     "domain_content_threshold" : 1.0,
#     "distribution_constraints" : {
#       "perform_comparison" : "Enabled",
#       "comparison_threshold" : 0.1,
#       "comparison_method" : "Robust"
#     }
#   }
# }
# 2020-10-29 21:13:09 INFO  FileUtil:29 - Write to file constraints.json at path /opt/ml/processing/output.
# 2020-10-29 21:13:09 INFO  StatsGenerator:65 - Generating Stats:
# 2020-10-29 21:13:09 INFO  CodeGenerator:54 - Code generated in 24.78321 ms
# 2020-10-29 21:13:09 INFO  CodeGenerator:54 - Code generated in 16.74249 ms
# 2020-10-29 21:13:09 INFO  SparkContext:54 - Starting job: count at StatsGenerator.scala:67
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Registering RDD 38 (count at StatsGenerator.scala:67)
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Got job 4 (count at StatsGenerator.scala:67) with 1 output partitions
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Final stage: ResultStage 7 (count at StatsGenerator.scala:67)
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Parents of final stage: List(ShuffleMapStage 6)
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Missing parents: List(ShuffleMapStage 6)
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Submitting ShuffleMapStage 6 (MapPartitionsRDD[38] at count at StatsGenerator.scala:67), which has no missing parents
# 2020-10-29 21:13:09 INFO  MemoryStore:54 - Block broadcast_9 stored as values in memory (estimated size 37.3 KB, free 1458.1 MB)
# 2020-10-29 21:13:09 INFO  MemoryStore:54 - Block broadcast_9_piece0 stored as bytes in memory (estimated size 15.9 KB, free 1458.1 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Added broadcast_9_piece0 in memory on 10.0.167.100:39949 (size: 15.9 KB, free: 1458.5 MB)
# 2020-10-29 21:13:09 INFO  SparkContext:54 - Created broadcast 9 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ShuffleMapStage 6 (MapPartitionsRDD[38] at count at StatsGenerator.scala:67) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:09 INFO  YarnScheduler:54 - Adding task set 6.0 with 1 tasks
# 2020-10-29 21:13:09 INFO  TaskSetManager:54 - Starting task 0.0 in stage 6.0 (TID 6, algo-1, executor 1, partition 0, PROCESS_LOCAL, 8333 bytes)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Added broadcast_9_piece0 in memory on algo-1:43127 (size: 15.9 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  TaskSetManager:54 - Finished task 0.0 in stage 6.0 (TID 6) in 75 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:09 INFO  YarnScheduler:54 - Removed TaskSet 6.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - ShuffleMapStage 6 (count at StatsGenerator.scala:67) finished in 0.099 s
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - looking for newly runnable stages
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - running: Set()
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - waiting: Set(ResultStage 7)
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - failed: Set()
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Submitting ResultStage 7 (MapPartitionsRDD[41] at count at StatsGenerator.scala:67), which has no missing parents
# 2020-10-29 21:13:09 INFO  MemoryStore:54 - Block broadcast_10 stored as values in memory (estimated size 7.4 KB, free 1458.1 MB)
# 2020-10-29 21:13:09 INFO  MemoryStore:54 - Block broadcast_10_piece0 stored as bytes in memory (estimated size 3.8 KB, free 1458.1 MB)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Added broadcast_10_piece0 in memory on 10.0.167.100:39949 (size: 3.8 KB, free: 1458.5 MB)
# 2020-10-29 21:13:09 INFO  SparkContext:54 - Created broadcast 10 from broadcast at DAGScheduler.scala:1039
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Submitting 1 missing tasks from ResultStage 7 (MapPartitionsRDD[41] at count at StatsGenerator.scala:67) (first 15 tasks are for partitions Vector(0))
# 2020-10-29 21:13:09 INFO  YarnScheduler:54 - Adding task set 7.0 with 1 tasks
# 2020-10-29 21:13:09 INFO  TaskSetManager:54 - Starting task 0.0 in stage 7.0 (TID 7, algo-1, executor 1, partition 0, NODE_LOCAL, 7765 bytes)
# 2020-10-29 21:13:09 INFO  BlockManagerInfo:54 - Added broadcast_10_piece0 in memory on algo-1:43127 (size: 3.8 KB, free: 5.8 GB)
# 2020-10-29 21:13:09 INFO  MapOutputTrackerMasterEndpoint:54 - Asked to send map output locations for shuffle 2 to 10.0.167.100:51538
# 2020-10-29 21:13:09 INFO  TaskSetManager:54 - Finished task 0.0 in stage 7.0 (TID 7) in 40 ms on algo-1 (executor 1) (1/1)
# 2020-10-29 21:13:09 INFO  YarnScheduler:54 - Removed TaskSet 7.0, whose tasks have all completed, from pool
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - ResultStage 7 (count at StatsGenerator.scala:67) finished in 0.063 s
# 2020-10-29 21:13:09 INFO  DAGScheduler:54 - Job 4 finished: count at StatsGenerator.scala:67, took 0.172733 s
# 2020-10-29 21:13:09 INFO  StatsGenerator:70 - Stats: {
#   "version" : 0.0,
#   "dataset" : {
#     "item_count" : 399
#   },
#   "features" : [ {
#     "name" : "_c0",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 3.0,
#       "distribution" : {
#         "categorical" : {
#           "buckets" : [ {
#             "value" : "0",
#             "count" : 256
#           }, {
#             "value" : "truth",
#             "count" : 1
#           }, {
#             "value" : "1",
#             "count" : 142
#           } ]
#         }
#       }
#     }
#   }, {
#     "name" : "_c1",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 347.0
#     }
#   }, {
#     "name" : "_c2",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 371.0
#     }
#   }, {
#     "name" : "_c3",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 355.0
#     }
#   }, {
#     "name" : "_c4",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 379.0
#     }
#   }, {
#     "name" : "_c5",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 375.0
#     }
#   }, {
#     "name" : "_c6",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 363.0
#     }
#   }, {
#     "name" : "_c7",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 363.0
#     }
#   }, {
#     "name" : "_c8",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 413.0
#     }
#   }, {
#     "name" : "_c9",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 382.0
#     }
#   }, {
#     "name" : "_c10",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 363.0
#     }
#   }, {
#     "name" : "_c11",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 373.0
#     }
#   }, {
#     "name" : "_c12",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 373.0
#     }
#   }, {
#     "name" : "_c13",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 394.0
#     }
#   }, {
#     "name" : "_c14",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 330.0
#     }
#   }, {
#     "name" : "_c15",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 379.0
#     }
#   }, {
#     "name" : "_c16",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 405.0
#     }
#   }, {
#     "name" : "_c17",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 397.0
#     }
#   }, {
#     "name" : "_c18",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 357.0
#     }
#   }, {
#     "name" : "_c19",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 359.0
#     }
#   }, {
#     "name" : "_c20",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 324.0
#     }
#   }, {
#     "name" : "_c21",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 361.0
#     }
#   }, {
#     "name" : "_c22",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 335.0
#     }
#   }, {
#     "name" : "_c23",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 371.0
#     }
#   }, {
#     "name" : "_c24",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 365.0
#     }
#   }, {
#     "name" : "_c25",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 333.0
#     }
#   }, {
#     "name" : "_c26",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 390.0
#     }
#   }, {
#     "name" : "_c27",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 384.0
#     }
#   }, {
#     "name" : "_c28",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 361.0
#     }
#   }, {
#     "name" : "_c29",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 351.0
#     }
#   }, {
#     "name" : "_c30",
#     "inferred_type" : "String",
#     "string_statistics" : {
#       "common" : {
#         "num_present" : 399,
#         "num_missing" : 0
#       },
#       "distinct_count" : 375.0
#     }
#   } ]
# }
# 2020-10-29 21:13:09 INFO  FileUtil:29 - Write to file statistics.json at path /opt/ml/processing/output.
# 2020-10-29 21:13:09 INFO  YarnClientSchedulerBackend:54 - Interrupting monitor thread
# 2020-10-29 21:13:09 INFO  YarnClientSchedulerBackend:54 - Shutting down all executors
# 2020-10-29 21:13:09 INFO  YarnSchedulerBackend$YarnDriverEndpoint:54 - Asking each executor to shut down
# 2020-10-29 21:13:09 INFO  SchedulerExtensionServices:54 - Stopping SchedulerExtensionServices
# (serviceOption=None,
#  services=List(),
#  started=false)
# 2020-10-29 21:13:09 INFO  YarnClientSchedulerBackend:54 - Stopped
# 2020-10-29 21:13:09 INFO  MapOutputTrackerMasterEndpoint:54 - MapOutputTrackerMasterEndpoint stopped!
# 2020-10-29 21:13:09 INFO  MemoryStore:54 - MemoryStore cleared
# 2020-10-29 21:13:09 INFO  BlockManager:54 - BlockManager stopped
# 2020-10-29 21:13:09 INFO  BlockManagerMaster:54 - BlockManagerMaster stopped
# 2020-10-29 21:13:09 INFO  OutputCommitCoordinator$OutputCommitCoordinatorEndpoint:54 - OutputCommitCoordinator stopped!
# 2020-10-29 21:13:09 INFO  SparkContext:54 - Successfully stopped SparkContext
# 2020-10-29 21:13:09 INFO  Main:62 - Completed: Job completed successfully with no violations.
# 2020-10-29 21:13:09 INFO  Main:138 - Write to file /opt/ml/output/message.
# 2020-10-29 21:13:09 INFO  ShutdownHookManager:54 - Shutdown hook called
# 2020-10-29 21:13:09 INFO  ShutdownHookManager:54 - Deleting directory /tmp/spark-780c4fde-fd8c-4822-88ae-ab462da31841
# 2020-10-29 21:13:09 INFO  ShutdownHookManager:54 - Deleting directory /tmp/spark-5b09af90-1733-4778-82ba-fa6770823436
# 2020-10-29 21:13:10,079 - DefaultDataAnalyzer - INFO - Completed spark-submit with return code : 0
# 2020-10-29 21:13:10,079 - DefaultDataAnalyzer - INFO - Spark job completed.

# %% [markdown]
# If you like, you can download the results from S3 and analyze. In the interest of time, we'll move on to setting up the monitoring schedule.

# %%
my_default_monitor.delete_monitoring_schedule()

# %%
from sagemaker.model_monitor import CronExpressionGenerator
from time import gmtime, strftime

mon_schedule_name = 'bi-hourly'
s3_report_path = 's3://{}/{}/model-monitor/monitoring-job-results'.format(bucket, prefix)

my_default_monitor.create_monitoring_schedule(
    monitor_schedule_name=mon_schedule_name,
    endpoint_input=endpoint_name,
    output_s3_uri=s3_report_path,
    statistics=my_default_monitor.baseline_statistics(),
    constraints=my_default_monitor.suggested_constraints(),
    schedule_cron_expression=CronExpressionGenerator.daily(),
    enable_cloudwatch_metrics=True)
# Out:
# Creating Monitoring Schedule with name: bi-hourly

# %%
# Out:
# Deleting Monitoring Schedule with name: bi-hourly

# %% [markdown]
# ---
# # Tune your model and re-deploy onto the SageMaker Endpoint
#
# Alright, we made it pretty far already! Now that we have monitoring enabled on this endpoint, let's imagine that something goes awry. We realize that we need a new model hosted on this RESTful API. How are we going to do that?

# %% [markdown]
# First, let's go about getting a new model. Given that the dataset here is pretty small, less than even 500 rows on the training set, why not try out AutoGluon? AutoGluon is a competitive choice here because it will actually augment our data for us. Said another way, Autogluon will make our original dataset larger by using Transformers and masking columns. Pretty cool!

# %%
# !mkdir src
# Out:
# mkdir: cannot create directory ‘src’: File exists

# %%
# %%writefile src/requirements.txt
#
# autogluon
# sagemaker
# awscli
# boto3
# PrettyTable
# bokeh
# numpy==1.16.1
# matplotlib
# sagemaker-experiments
# Out:
# Overwriting src/requirements.txt

# %%
# %%writefile src/train.py

import ast
import argparse
import logging
import warnings
import os
import json
import glob
import subprocess
import sys
import boto3
import pickle
import pandas as pd
from collections import Counter
from timeit import default_timer as timer
import time

from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

sys.path.insert(0, 'package')
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    from prettytable import PrettyTable
    import autogluon as ag
    from autogluon import TabularPrediction as task
    from autogluon.task.tabular_prediction import TabularDataset
    
# ------------------------------------------------------------ #
# Training methods                                             #
# ------------------------------------------------------------ #

def du(path):
    """disk usage in human readable format (e.g. '2,1GB')"""
    return subprocess.check_output(['du','-sh', path]).split()[0].decode('utf-8')

def __load_input_data(path: str) -> TabularDataset:
    """
    Load training data as dataframe
    :param path:
    :return: DataFrame
    """
    input_data_files = os.listdir(path)
    try:
        input_dfs = [pd.read_csv(f'{path}/{data_file}') for data_file in input_data_files]
        return task.Dataset(df=pd.concat(input_dfs))
    except:
        print(f'No csv data in {path}!')
        return None

def train(args):
        
    is_distributed = len(args.hosts) > 1
    host_rank = args.hosts.index(args.current_host)    
    dist_ip_addrs = args.hosts
    dist_ip_addrs.pop(host_rank)
    ngpus_per_trial = 1 if args.num_gpus > 0 else 0

    # load training and validation data
    print(f'Train files: {os.listdir(args.train)}')
    train_data = __load_input_data(args.train)
    print(f'Label counts: {dict(Counter(train_data[args.label]))}')
    
    predictor = task.fit(
        train_data=train_data,
        label=args.label,            
        output_directory=args.model_dir,
        problem_type=args.problem_type,
        eval_metric=args.eval_metric,
        stopping_metric=args.stopping_metric,
        auto_stack=args.auto_stack, # default: False
        hyperparameter_tune=args.hyperparameter_tune, # default: False
        feature_prune=args.feature_prune, # default: False
        holdout_frac=args.holdout_frac, # default: None
        num_bagging_folds=args.num_bagging_folds, # default: 0
        num_bagging_sets=args.num_bagging_sets, # default: None
        stack_ensemble_levels=args.stack_ensemble_levels, # default: 0
        cache_data=args.cache_data,
        time_limits=args.time_limits,
        num_trials=args.num_trials, # default: None
        search_strategy=args.search_strategy, # default: 'random'
        search_options=args.search_options,
        visualizer=args.visualizer,
        verbosity=args.verbosity
    )
    
    # Results summary
    predictor.fit_summary(verbosity=1)

    # Leaderboard on optional test data
    if args.test:
        print(f'Test files: {os.listdir(args.test)}')
        test_data = __load_input_data(args.test)    
        print('Running model on test data and getting Leaderboard...')
        leaderboard = predictor.leaderboard(dataset=test_data, silent=True)
        def format_for_print(df):
            table = PrettyTable(list(df.columns))
            for row in df.itertuples():
                table.add_row(row[1:])
            return str(table)
        print(format_for_print(leaderboard), end='\n\n')

    # Files summary
    print(f'Model export summary:')
    print(f"/opt/ml/model/: {os.listdir('/opt/ml/model/')}")
    models_contents = os.listdir('/opt/ml/model/models')
    print(f"/opt/ml/model/models: {models_contents}")
    print(f"/opt/ml/model directory size: {du('/opt/ml/model/')}\n")

# ------------------------------------------------------------ #
# Training execution                                           #
# ------------------------------------------------------------ #

def str2bool(v):
    return v.lower() in ('yes', 'true', 't', '1')

def parse_args():

    parser = argparse.ArgumentParser(
             formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.register('type','bool',str2bool) # add type keyword to registries

    parser.add_argument('--hosts', type=list, default=json.loads(os.environ['SM_HOSTS']))    
    parser.add_argument('--current-host', type=str, default=os.environ['SM_CURRENT_HOST'])
    parser.add_argument('--num-gpus', type=int, default=os.environ['SM_NUM_GPUS'])
    parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR']) # /opt/ml/model
    parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAINING'])
    parser.add_argument('--test', type=str, default='') # /opt/ml/input/data/test
    parser.add_argument('--label', type=str, default='truth',
                        help="Name of the column that contains the target variable to predict.")
    
    parser.add_argument('--problem_type', type=str, default=None,
                        help=("Type of prediction problem, i.e. is this a binary/multiclass classification or "
                              "regression problem options: 'binary', 'multiclass', 'regression'). "
                              "If `problem_type = None`, the prediction problem type is inferred based "
                              "on the label-values in provided dataset."))
    parser.add_argument('--eval_metric', type=str, default=None,
                        help=("Metric by which predictions will be ultimately evaluated on test data."
                              "AutoGluon tunes factors such as hyperparameters, early-stopping, ensemble-weights, etc. "
                              "in order to improve this metric on validation data. "
                              "If `eval_metric = None`, it is automatically chosen based on `problem_type`. "
                              "Defaults to 'accuracy' for binary and multiclass classification and "
                              "'root_mean_squared_error' for regression. "
                              "Otherwise, options for classification: [ "
                              "    'accuracy', 'balanced_accuracy', 'f1', 'f1_macro', 'f1_micro', 'f1_weighted', "
                              "    'roc_auc', 'average_precision', 'precision', 'precision_macro', 'precision_micro', 'precision_weighted', "
                              "    'recall', 'recall_macro', 'recall_micro', 'recall_weighted', 'log_loss', 'pac_score']. "
                              "Options for regression: ['root_mean_squared_error', 'mean_squared_error', "
                              "'mean_absolute_error', 'median_absolute_error', 'r2']. "
                              "For more information on these options, see `sklearn.metrics`: "
                              "https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics "
                              "You can also pass your own evaluation function here as long as it follows formatting of the functions "
                              "defined in `autogluon/utils/tabular/metrics/`. "))
    parser.add_argument('--stopping_metric', type=str, default=None,
                        help=("Metric which models use to early stop to avoid overfitting. "
                              "`stopping_metric` is not used by weighted ensembles, instead weighted ensembles maximize `eval_metric`. "
                              "Defaults to `eval_metric` value except when `eval_metric='roc_auc'`, where it defaults to `log_loss`."))      
    parser.add_argument('--auto_stack', type='bool', default=False,
                        help=("Whether to have AutoGluon automatically attempt to select optimal "
                              "num_bagging_folds and stack_ensemble_levels based on data properties. "
                              "Note: Overrides num_bagging_folds and stack_ensemble_levels values. "
                              "Note: This can increase training time by up to 20x, but can produce much better results. "
                              "Note: This can increase inference time by up to 20x."))
    parser.add_argument('--hyperparameter_tune', type='bool', default=False,
                        help=("Whether to tune hyperparameters or just use fixed hyperparameter values "
                              "for each model. Setting as True will increase `fit()` runtimes."))
    parser.add_argument('--feature_prune', type='bool', default=False,
                        help="Whether or not to perform feature selection.")
    parser.add_argument('--holdout_frac', type=float, default=None, 
                        help=("Fraction of train_data to holdout as tuning data for optimizing hyperparameters "
                              "(ignored unless `tuning_data = None`, ignored if `num_bagging_folds != 0`). "
                              "Default value is selected based on the number of rows in the training data. "
                              "Default values range from 0.2 at 2,500 rows to 0.01 at 250,000 rows. "
                              "Default value is doubled if `hyperparameter_tune = True`, up to a maximum of 0.2. "
                              "Disabled if `num_bagging_folds >= 2`."))    
    parser.add_argument('--num_bagging_folds', type=int, default=0, 
                        help=("Number of folds used for bagging of models. When `num_bagging_folds = k`, "
                              "training time is roughly increased by a factor of `k` (set = 0 to disable bagging). "
                              "Disabled by default, but we recommend values between 5-10 to maximize predictive performance. "
                              "Increasing num_bagging_folds will result in models with lower bias but that are more prone to overfitting. "
                              "Values > 10 may produce diminishing returns, and can even harm overall results due to overfitting. "
                              "To further improve predictions, avoid increasing num_bagging_folds much beyond 10 "
                              "and instead increase num_bagging_sets. "))    
    parser.add_argument('--num_bagging_sets', type=int, default=None,
                        help=("Number of repeats of kfold bagging to perform (values must be >= 1). "
                              "Total number of models trained during bagging = num_bagging_folds * num_bagging_sets. "
                              "Defaults to 1 if time_limits is not specified, otherwise 20 "
                              "(always disabled if num_bagging_folds is not specified). "
                              "Values greater than 1 will result in superior predictive performance, "
                              "especially on smaller problems and with stacking enabled. "
                              "Increasing num_bagged_sets reduces the bagged aggregated variance without "
                              "increasing the amount each model is overfit."))
    parser.add_argument('--stack_ensemble_levels', type=int, default=0, 
                        help=("Number of stacking levels to use in stack ensemble. "
                              "Roughly increases model training time by factor of `stack_ensemble_levels+1` " 
                              "(set = 0 to disable stack ensembling).  "
                              "Disabled by default, but we recommend values between 1-3 to maximize predictive performance. "
                              "To prevent overfitting, this argument is ignored unless you have also set `num_bagging_folds >= 2`."))
    parser.add_argument('--hyperparameters', type=lambda s: ast.literal_eval(s), default=None,
                        help="Refer to docs: https://autogluon.mxnet.io/api/autogluon.task.html")
    parser.add_argument('--cache_data', type='bool', default=True,
                       help=("Whether the predictor returned by this `fit()` call should be able to be further trained "
                             "via another future `fit()` call. "
                             "When enabled, the training and validation data are saved to disk for future reuse."))
    parser.add_argument('--time_limits', type=int, default=None, 
                        help=("Approximately how long `fit()` should run for (wallclock time in seconds)."
                              "If not specified, `fit()` will run until all models have completed training, "
                              "but will not repeatedly bag models unless `num_bagging_sets` is specified."))
    parser.add_argument('--num_trials', type=int, default=None, 
                        help=("Maximal number of different hyperparameter settings of each "
                              "model type to evaluate during HPO. (only matters if "
                              "hyperparameter_tune = True). If both `time_limits` and "
                              "`num_trials` are specified, `time_limits` takes precedent."))    
    parser.add_argument('--search_strategy', type=str, default='random',
                        help=("Which hyperparameter search algorithm to use. "
                              "Options include: 'random' (random search), 'skopt' "
                              "(SKopt Bayesian optimization), 'grid' (grid search), "
                              "'hyperband' (Hyperband), 'rl' (reinforcement learner)"))      
    parser.add_argument('--search_options', type=lambda s: ast.literal_eval(s), default=None,
                        help="Auxiliary keyword arguments to pass to the searcher that performs hyperparameter optimization.")
    parser.add_argument('--nthreads_per_trial', type=int, default=None,
                        help="How many CPUs to use in each training run of an individual model. This is automatically determined by AutoGluon when left as None (based on available compute).")
    parser.add_argument('--ngpus_per_trial', type=int, default=None,
                        help="How many GPUs to use in each trial (ie. single training run of a model). This is automatically determined by AutoGluon when left as None.")
    parser.add_argument('--dist_ip_addrs', type=list, default=None,
                        help="List of IP addresses corresponding to remote workers, in order to leverage distributed computation.") 
    parser.add_argument('--visualizer', type=str, default='none',
                        help=("How to visualize the neural network training progress during `fit()`. "
                              "Options: ['mxboard', 'tensorboard', 'none']."))          
    parser.add_argument('--verbosity', type=int, default=2, 
                        help=("Verbosity levels range from 0 to 4 and control how much information is printed during fit(). "
                              "Higher levels correspond to more detailed print statements (you can set verbosity = 0 to suppress warnings). "
                              "If using logging, you can alternatively control amount of information printed via `logger.setLevel(L)`, "
                              "where `L` ranges from 0 to 50 (Note: higher values of `L` correspond to fewer print statements, "
                              "opposite of verbosity levels"))
    parser.add_argument('--debug', type='bool', default=False,
                       help=("Whether to set logging level to DEBUG"))  
        
    parser.add_argument('--feature_importance', type='bool', default=True)

    return parser.parse_args()


def set_experiment_config(experiment_basename = None):
    '''
    Optionally takes an base name for the experiment. Has a hard dependency on boto3 installation. 
    Creates a new experiment using the basename, otherwise simply uses autogluon as basename.
    May run into issues on Experiments' requirements for basename config downstream.
    '''
    now = int(time.time())
    
    if experiment_basename:
        experiment_name = '{}-autogluon-{}'.format(experiment_basename, now)
    else:
        experiment_name = 'autogluon-{}'.format(now)
    
    try:
        client = boto3.Session().client('sagemaker')
    except:
        print ('You need to install boto3 to create an experiment. Try pip install --upgrade boto3')
        return ''
    
    try:
        Experiment.create(experiment_name=experiment_name, 
                            description="Running AutoGluon Tabular with SageMaker Experiments", 
                            sagemaker_boto_client=client)
        print ('Created an experiment named {}, you should be able to see this in SageMaker Studio right now.'.format(experiment_name))
        
    except:
        print ('Could not create the experiment. Is your basename properly configured? Also try installing the sagemaker experiments SDK with pip install sagemaker-experiments.')
        return ''
    
    return experiment_name

if __name__ == "__main__":
    start = timer()

    args = parse_args()
        
    # Print SageMaker args
    print('\n====== args ======')
    for k,v in vars(args).items():
        print(f'{k},  type: {type(v)},  value: {v}')
    print()
    
    train()

    # Package inference code with model export
    subprocess.call('mkdir /opt/ml/model/code'.split())
    subprocess.call('cp /opt/ml/code/inference.py /opt/ml/model/code/'.split())
    
    elapsed_time = round(timer()-start,3)
    print(f'Elapsed time: {elapsed_time} seconds')  
    print('===== Training Completed =====')
# Out:
# Overwriting src/train.py

# %%
from sagemaker.mxnet.estimator import MXNet
from sagemaker import get_execution_role

role = get_execution_role()

estimator = MXNet(source_dir = 'src',
                    entry_point = 'train.py',
                    role=role,
                    framework_version = '1.7.0',
                    py_version = 'py3',
                    instance_count=1,
                    instance_type='ml.m5.2xlarge',
                    volume_size=100)         

s3_path = 's3://sagemaker-us-east-1-138066269299/model-hosting/train/train_set.csv'

estimator.fit(s3_path, wait=False)

# %%
# from sagemaker.sklearn.estimator import SKLearn
# from sagemaker import get_execution_role

# script_path = 'train.py'

# # first, let's get the estimator defined 
# est = SKLearn(entry_point=script_path,
#                 instance_type="ml.c4.xlarge",
#                 instance_count = 1,
#                 role=role,
#                 sagemaker_session=sess,
#                 py_version = 'py3',
#                 framework_version = '0.20.0')

# # then, let's set up the tuning framework 
# from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

# hyperparameter_ranges = {'lr': ContinuousParameter(0.00001, 0.001),
#                          'batch-size': IntegerParameter(25, 300)}

# %%
# objective_metric_name = 'Accuracy'
# objective_type = 'Maximize'
# metric_definitions = [{'Name': 'Accuracy',
#                        'Regex': 'Accuracy: ([0-9\\.]+)'}]

# %%
# tuner = HyperparameterTuner(est,
#                             objective_metric_name,
#                             hyperparameter_ranges,
#                             metric_definitions,
#                             max_jobs=20,
#                             max_parallel_jobs=3,
#                             objective_type=objective_type)

# %%
# msg = 'aws s3 cp test_set.csv s3://{}/{}/ && aws s3 cp train_set.csv s3://{}/{}/'.format(bucket, prefix, bucket, prefix)
# os.system(msg)

# %%
# # may complain about not wanting headers 
# inputs = {'train': 's3://{}/{}/train_set.csv'.format(bucket, prefix),
#           'test': 's3://{}/{}/test_set.csv'.format(bucket, prefix)}

# %%
# tuner.fit(inputs)

# %% [markdown]
# ### Redeploy to existing SageMaker Endpoint

# %%
from sagemaker.tuner import HyperparameterTuner

job_name = 'sagemaker-scikit-lea-201014-1830'

tuner = HyperparameterTuner.attach(job_name)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFound                          Traceback (most recent call last)
# <ipython-input-59-16b785c73b0b> in <module>
#       3 job_name = 'sagemaker-scikit-lea-201014-1830'
#       4
# ----> 5 tuner = HyperparameterTuner.attach(job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/tuner.py in attach(cls, tuning_job_name, sagemaker_session, job_details, estimator_cls)
#     601         if job_details is None:
#     602             job_details = sagemaker_session.sagemaker_client.describe_hyper_parameter_tuning_job(
# --> 603                 HyperParameterTuningJobName=tuning_job_name
#     604             )
#     605
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ResourceNotFound: An error occurred (ResourceNotFound) when calling the DescribeHyperParameterTuningJob operation: Amazon SageMaker can't find a tuning job called sagemaker-scikit-lea-201014-1830. Type another name.

# %%
best_estimator = tuner.best_estimator()

# %%
model = best_estimator.create_model()
model_name = model.name

# %%
import boto3
import random
import time
import datetime

def create_model(model, now):
    sm_client = boto3.client('sagemaker')
    
    x = random.randint(1, 100)
    
    model_name = '{}-{}'.format(model.name, now)
    
    response = sm_client.create_model(ModelName=model_name,
            PrimaryContainer={'ContainerHostname': 'string','Image': model.image_uri, 'ModelDataUrl': model.model_data},
            ExecutionRoleArn= 'arn:aws:iam::181880743555:role/service-role/AmazonSageMaker-ExecutionRole-20200929T125134')

    return response

def get_endpoint_config(model_name, now):
    
    sm_client = boto3.client('sagemaker')

    endpoint_config_name = 'ec-{}-{}'.format(model_name, now)
    
    response = sm_client.create_endpoint_config(EndpointConfigName= endpoint_config_name,
                                            ProductionVariants=[{'VariantName': 'v-{}'.format(model_name),
                                                                    'ModelName': model_name,
                                                                    'InitialInstanceCount': 1,
                                                                    'InstanceType':'ml.m5.large'}])
    return endpoint_config_name

def update_endpoint(model_name, endpoint_name, now):
    
    sm_client = boto3.client('sagemaker')

    endpoint_config = get_endpoint_config(model_name, now)
    
    # deregister a scaling policy 
    resource_id = get_resource_id(endpoint_name)
    
    client = boto3.client('application-autoscaling')
    
    
    try:
        response = client.deregister_scalable_target(ServiceNamespace='sagemaker',
                                                    ResourceId=resource_id,
                                                    ScalableDimension='sagemaker:variant:DesiredInstanceCount')
        
    except:
        print ('no autoscaling policy to deregister, continuing')
    # get monitoring schedules
    
    try:
        response = sm_client.list_monitoring_schedules(EndpointName=endpoint_name,
                                                    MaxResults=10,
                                                    StatusEquals='Scheduled')
        # delete monitoring schedules 
        for each in response['MonitoringScheduleSummaries']:
            name = each['MonitoringScheduleName']
            response = sm_client.delete_monitoring_schedule(MonitoringScheduleName=name)
            
    except:
        print ('already deleted the monitoring schedules')
    
    response = sm_client.update_endpoint(EndpointName=endpoint_name,
                                        EndpointConfigName=endpoint_config)
    
    return response

                                
now = str(datetime.datetime.now()).split('.')[-1]
                                
endpoint_name = 'sagemaker-scikit-learn-2020-10-14-15-12-50-644'

create_model(model, now)

update_endpoint(model_name, endpoint_name, now)

# %% [markdown]
# ---
# # Automate with Notebook Runner
# Now we're able to monitor new endpoints, we want the ability to automate this whole flow so that we can do it rapidly. As it so happens, a simple and fast way of doing that is using SageMaker processing jobs, CloudWatch, and Lambda. Luckily we can import all of the infrastructure we need using a simple toolkit, which we'll step through here.
#
# GitHub notes are right here: https://github.com/aws-samples/sagemaker-run-notebook

# %%
# todo - make sure they have the right execution role here, add cfn all access, then a trust relationship, then inlines to allow create stack, plus codebuild create project nad start build

# %%
# !wget https://github.com/aws-samples/sagemaker-run-notebook/releases/download/v0.15.0/sagemaker_run_notebook-0.15.0.tar.gz

# %%
# !pip install sagemaker_run_notebook-0.15.0.tar.gz

# %%
# !run-notebook create-infrastructure --update

# %%
# %%writefile requirements.txt
# awscli
# boto3
# sagemaker
# pandas
# sklearn

# %%
# !run-notebook create-container --requirements requirements.txt

# %%
# !wget https://github.com/aws-samples/sagemaker-run-notebook/releases/download/v0.15.0/install-run-notebook.sh

# %% [markdown]
# Next, __you need to open a system terminal on Studio, cd into the directory where we just downloaded `install-run-notebook.sh`, and run the command `bash install-run-notebook.sh`.__ This will run for a few minutes, then prompt you to refresh your web browser. Do that, and you'll see a new Jupyter Widget!

# %% [markdown]
# After restarting your Studio page, click on the spaceship widget on the top lefthand side of your Stuio domain view. Make sure you're actually looking at an ipython notebook while you do this.
#
# Using the widget is super simple. Paste in your execution role, which you can find by running `sagemaker.get_execution_role()` locally. Then paste in your ECR image repository, which you can find by opening up the ECR page in the AWS console. It should default to `notebook-runner`, so you can just paste that in directly.
#
# Then click the big blue `run now` button, and __this entire notebook is going to run on a SageMaker processing job.__

# %% [markdown]
# Before you do that, you'll want to comment-out those last few cells you ran to install this toolkit and get the infrastructure up and running.

# %% [markdown]
# If you want, you can parameterize this entire notebook using Papermill. Read more about how to do that with the following resources:
# - Blog post: https://aws.amazon.com/blogs/machine-learning/scheduling-jupyter-notebooks-on-sagemaker-ephemeral-instances/
# - GitHub repository: https://github.com/aws-samples/sagemaker-run-notebook
